# %%
##  "attacks" folder (with attack csv files) is required for the operation of the program.
##  "attacks" folder must be located in the same directory as the program.


##  the purpose of this code is to determine which features to use in the machine learning phase.
##  for this purpose, the importance weights of the attacks are calculated.
##  this calculation was made using sklearn-RandomForestRegressor.

##  the some codes parts used for calculation and graphing are taken from the following site.
##  http://scikit-learn.org/stable/auto_examples/ensemble/plot_forest_importances.html

import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestRegressor
import sklearn as sk
import time
seconds = time.time()

def folder(f_name): #this function creates a folder named "feaure_pics" in the program directory.
    try:
        if not os.path.exists(f_name):
            os.makedirs(f_name)
    except OSError:
        print ("The folder could not be created!")
        

# CSV files names:
csv_files=os.listdir("attacks")# It creates a list of file names in the "attacks" folder.

# Headers of column
main_labels=["Flow Duration","Total Fwd Packets",   "Total Backward Packets","Total Length of Fwd Packets","Total Length of Bwd Packets","Fwd Packet Length Max","Fwd Packet Length Min",
   "Fwd Packet Length Mean","Fwd Packet Length Std","Bwd Packet Length Max","Bwd Packet Length Min","Bwd Packet Length Mean","Bwd Packet Length Std",
   "Flow Bytes/s","Flow Packets/s","Flow IAT Mean","Flow IAT Std","Flow IAT Max","Flow IAT Min","Fwd IAT Total","Fwd IAT Mean","Fwd IAT Std","Fwd IAT Max",
   "Fwd IAT Min","Bwd IAT Total","Bwd IAT Mean","Bwd IAT Std","Bwd IAT Max","Bwd IAT Min","Fwd PSH Flags","Bwd PSH Flags","Fwd URG Flags","Bwd URG Flags",
   "Fwd Header Length","Bwd Header Length","Fwd Packets/s","Bwd Packets/s","Min Packet Length","Max Packet Length","Packet Length Mean","Packet Length Std",
   "Packet Length Variance","FIN Flag Count","SYN Flag Count","RST Flag Count","PSH Flag Count","ACK Flag Count","URG Flag Count","CWE Flag Count",
   "ECE Flag Count","Down/Up Ratio","Average Packet Size","Avg Fwd Segment Size","Avg Bwd Segment Size","Fwd Avg Bytes/Bulk",
   "Fwd Avg Packets/Bulk","Fwd Avg Bulk Rate","Bwd Avg Bytes/Bulk","Bwd Avg Packets/Bulk","Bwd Avg Bulk Rate","Subflow Fwd Packets","Subflow Fwd Bytes",
   "Subflow Bwd Packets","Subflow Bwd Bytes","Init_Win_bytes_forward","Init_Win_bytes_backward","act_data_pkt_fwd",
   "min_seg_size_forward","Active Mean","Active Std","Active Max","Active Min",
    "Idle Mean","Idle Std","Idle Max", "Idle Min","Label"]

ths = open("importance_list_for_attack_files.csv", "w")
folder("./feaure_pics/")
for j in csv_files:
    df=pd.read_csv(".\\attacks\\"+j,usecols=main_labels)
    df=df.fillna(0)
    attack_or_not=[]
    for i in df["Label"]:#it changes the normal label to "1" and the attack tag to "0" for use in the machine learning algorithm
        if i =="BENIGN":
            attack_or_not.append(1)
        else:
            attack_or_not.append(0)           
    df["Label"]=attack_or_not

    y = df["Label"].values
    del df["Label"]
    X = df.values
    
    X = np.float32(X)
    X[np.isnan(X)] = 0
    X[np.isinf(X)] = 0
   

    #computing the feature importances
    forest = sk.ensemble.RandomForestRegressor(n_estimators=250,random_state=0)
    forest.fit(X, y)
    importances = forest.feature_importances_
    std = np.std([tree.feature_importances_ for tree in forest.estimators_],
                 axis=0)
    indices = np.argsort(importances)[::-1]
    refclasscol=list(df.columns.values)
    impor_bars = pd.DataFrame({'Features':refclasscol[0:20],'importance':importances[0:20]})
    impor_bars = impor_bars.sort_values('importance',ascending=False).set_index('Features')
    plt.rcParams['figure.figsize'] = (10, 5)
    impor_bars.plot.bar();
    #printing the feature importances  
    count=0
    fea_ture=j[0:-4]+"=["
    for i in impor_bars.index:
        fea_ture=fea_ture+"\""+str(i)+"\","
        count+=1
        if count==5:
            fea_ture=fea_ture[0:-1]+"]"
            break     
    print(j[0:-4],"importance list:")
    print(j[0:-4],"\n",impor_bars.head(20),"\n\n\n")
    print(fea_ture)
    plt.title(j[0:-4]+" Attack - Feature Importance")
    plt.ylabel('Importance')
    plt.savefig("./feaure_pics/"+j[0:-4]+".pdf",bbox_inches='tight', papertype = 'a4', orientation = 'portrait', format = 'pdf')
    ths.write((  fea_ture ) )
    plt.tight_layout()
    plt.show()
    print("-----------------------------------------------------------------------------------------------\n\n\n\n")

    
print("mission accomplished!")
print("Total operation time: = ",time.time()- seconds ,"seconds")
ths.close()
# Out:
# Bot importance list:
# Bot
#                               importance
# Features
# Bwd Packet Length Mean         0.350853
# Flow IAT Mean                  0.025827
# Flow IAT Min                   0.009944
# Flow Duration                  0.006009
# Flow IAT Std                   0.005610
# Flow IAT Max                   0.003038
# Flow Bytes/s                   0.000907
# Flow Packets/s                 0.000842
# Bwd Packet Length Max          0.000245
# Total Length of Bwd Packets    0.000213
# Total Backward Packets         0.000185
# Total Length of Fwd Packets    0.000103
# Fwd IAT Total                  0.000102
# Total Fwd Packets              0.000071
# Fwd Packet Length Std          0.000068
# Bwd Packet Length Std          0.000049
# Fwd Packet Length Min          0.000047
# Fwd Packet Length Mean         0.000034
# Fwd Packet Length Max          0.000011
# Bwd Packet Length Min          0.000000
#
#
#
# Bot=["Bwd Packet Length Mean","Flow IAT Mean","Flow IAT Min","Flow Duration","Flow IAT Std"]
# C:\Users\dhira\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\ipykernel_launcher.py:95: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error in 3.6
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DDoS importance list:
# DDoS
#                               importance
# Features
# Bwd Packet Length Std          0.471250
# Total Backward Packets         0.094381
# Fwd IAT Total                  0.009724
# Total Length of Fwd Packets    0.007132
# Flow Bytes/s                   0.006858
# Flow Duration                  0.006442
# Flow IAT Min                   0.006157
# Flow IAT Std                   0.005546
# Flow IAT Mean                  0.005172
# Flow IAT Max                   0.004538
# Fwd Packet Length Max          0.001338
# Fwd Packet Length Std          0.001114
# Flow Packets/s                 0.001011
# Fwd Packet Length Mean         0.000613
# Bwd Packet Length Max          0.000600
# Bwd Packet Length Min          0.000462
# Bwd Packet Length Mean         0.000212
# Total Length of Bwd Packets    0.000149
# Total Fwd Packets              0.000035
# Fwd Packet Length Min          0.000024
#
#
#
# DDoS=["Bwd Packet Length Std","Total Backward Packets","Fwd IAT Total","Total Length of Fwd Packets","Flow Bytes/s"]
# C:\Users\dhira\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\ipykernel_launcher.py:95: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error in 3.6
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DoS GoldenEye importance list:
# DoS GoldenEye
#                               importance
# Features
# Flow IAT Max                   0.461131
# Bwd Packet Length Std          0.069298
# Flow IAT Min                   0.045409
# Total Backward Packets         0.028428
# Fwd Packet Length Min          0.006486
# Flow IAT Mean                  0.003427
# Flow IAT Std                   0.002329
# Bwd Packet Length Mean         0.001460
# Fwd IAT Total                  0.001181
# Flow Bytes/s                   0.001154
# Fwd Packet Length Max          0.000727
# Flow Duration                  0.000716
# Flow Packets/s                 0.000351
# Bwd Packet Length Max          0.000315
# Bwd Packet Length Min          0.000305
# Total Length of Bwd Packets    0.000275
# Total Length of Fwd Packets    0.000248
# Fwd Packet Length Std          0.000179
# Total Fwd Packets              0.000048
# Fwd Packet Length Mean         0.000039
#
#
#
# DoS GoldenEye=["Flow IAT Max","Bwd Packet Length Std","Flow IAT Min","Total Backward Packets","Fwd Packet Length Min"]
# C:\Users\dhira\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\ipykernel_launcher.py:95: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error in 3.6
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DoS Hulk importance list:
# DoS Hulk
#                                 importance
# Features
# Bwd Packet Length Std        5.142541e-01
# Fwd Packet Length Std        7.783416e-02
# Flow IAT Min                 1.889176e-03
# Flow Duration                1.689411e-03
# Fwd Packet Length Max        7.399973e-04
# Total Backward Packets       3.462036e-04
# Fwd IAT Total                1.891993e-04
# Total Length of Bwd Packets  1.707227e-04
# Flow IAT Max                 1.295087e-04
# Flow IAT Std                 1.262044e-04
# Flow IAT Mean                8.475489e-05
# Flow Packets/s               7.660413e-05
# Bwd Packet Length Mean       4.158971e-05
# Flow Bytes/s                 2.178251e-05
# Bwd Packet Length Max        1.013306e-05
# Fwd Packet Length Mean       9.768455e-06
# Bwd Packet Length Min        8.751241e-06
# Total Fwd Packets            7.319843e-06
# Total Length of Fwd Packets  4.511786e-06
# Fwd Packet Length Min        4.513760e-08
#
#
#
# DoS Hulk=["Bwd Packet Length Std","Fwd Packet Length Std","Flow IAT Min","Flow Duration","Fwd Packet Length Max"]
# C:\Users\dhira\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\ipykernel_launcher.py:95: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error in 3.6
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DoS Slowhttptest importance list:
# DoS Slowhttptest
#                               importance
# Features
# Flow IAT Mean                  0.654343
# Fwd Packet Length Min          0.108099
# Total Length of Bwd Packets    0.020228
# Bwd Packet Length Mean         0.019395
# Bwd Packet Length Std          0.006722
# Bwd Packet Length Max          0.003326
# Flow IAT Min                   0.002506
# Fwd Packet Length Mean         0.001883
# Fwd Packet Length Std          0.001035
# Fwd Packet Length Max          0.000787
# Bwd Packet Length Min          0.000526
# Total Fwd Packets              0.000490
# Flow Bytes/s                   0.000482
# Flow Duration                  0.000454
# Fwd IAT Total                  0.000326
# Flow IAT Max                   0.000261
# Total Length of Fwd Packets    0.000227
# Total Backward Packets         0.000213
# Flow IAT Std                   0.000091
# Flow Packets/s                 0.000069
#
#
#
# DoS Slowhttptest=["Flow IAT Mean","Fwd Packet Length Min","Total Length of Bwd Packets","Bwd Packet Length Mean","Bwd Packet Length Std"]
# C:\Users\dhira\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\ipykernel_launcher.py:95: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error in 3.6
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DoS slowloris importance list:
# DoS slowloris
#                               importance
# Features
# Flow IAT Mean                  0.471187
# Bwd Packet Length Mean         0.120792
# Total Fwd Packets              0.006744
# Fwd IAT Total                  0.001582
# Flow IAT Max                   0.001521
# Flow Duration                  0.001491
# Total Length of Bwd Packets    0.001448
# Flow IAT Min                   0.001338
# Fwd Packet Length Max          0.000935
# Flow Bytes/s                   0.000903
# Bwd Packet Length Max          0.000709
# Fwd Packet Length Std          0.000632
# Bwd Packet Length Std          0.000596
# Flow Packets/s                 0.000499
# Flow IAT Std                   0.000431
# Total Backward Packets         0.000376
# Total Length of Fwd Packets    0.000334
# Fwd Packet Length Mean         0.000306
# Fwd Packet Length Min          0.000070
# Bwd Packet Length Min          0.000007
#
#
#
# DoS slowloris=["Flow IAT Mean","Bwd Packet Length Mean","Total Fwd Packets","Fwd IAT Total","Flow IAT Max"]
# C:\Users\dhira\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\ipykernel_launcher.py:95: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error in 3.6
# -----------------------------------------------------------------------------------------------
#
#
#
#
# FTP-Patator importance list:
# FTP-Patator
#                               importance
# Features
# Fwd Packet Length Max          0.258408
# Fwd Packet Length Std          0.027012
# Fwd Packet Length Mean         0.010632
# Bwd Packet Length Mean         0.000729
# Flow IAT Min                   0.000203
# Bwd Packet Length Max          0.000197
# Total Fwd Packets              0.000173
# Total Length of Bwd Packets    0.000165
# Bwd Packet Length Std          0.000092
# Flow Duration                  0.000078
# Flow IAT Max                   0.000074
# Flow IAT Mean                  0.000063
# Total Backward Packets         0.000052
# Total Length of Fwd Packets    0.000051
# Fwd IAT Total                  0.000040
# Flow Packets/s                 0.000035
# Flow IAT Std                   0.000027
# Bwd Packet Length Min          0.000024
# Fwd Packet Length Min          0.000006
# Flow Bytes/s                   0.000002
#
#
#
# FTP-Patator=["Fwd Packet Length Max","Fwd Packet Length Std","Fwd Packet Length Mean","Bwd Packet Length Mean","Flow IAT Min"]
# C:\Users\dhira\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\ipykernel_launcher.py:95: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error in 3.6
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Heartbleed importance list:
# Heartbleed
#                               importance
# Features
# Bwd Packet Length Mean            0.076
# Bwd Packet Length Max             0.068
# Total Fwd Packets                 0.064
# Total Backward Packets            0.052
# Total Length of Bwd Packets       0.048
# Flow Duration                     0.032
# Bwd Packet Length Std             0.012
# Fwd IAT Total                     0.012
# Total Length of Fwd Packets       0.008
# Flow IAT Min                      0.004
# Fwd Packet Length Std             0.000
# Fwd Packet Length Mean            0.000
# Fwd Packet Length Min             0.000
# Fwd Packet Length Max             0.000
# Flow Bytes/s                      0.000
# Flow Packets/s                    0.000
# Flow IAT Mean                     0.000
# Flow IAT Std                      0.000
# Flow IAT Max                      0.000
# Bwd Packet Length Min             0.000
#
#
#
# Heartbleed=["Bwd Packet Length Mean","Bwd Packet Length Max","Total Fwd Packets","Total Backward Packets","Total Length of Bwd Packets"]
# C:\Users\dhira\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\ipykernel_launcher.py:95: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error in 3.6
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Infiltration importance list:
# Infiltration
#                               importance
# Features
# Total Length of Fwd Packets    0.057053
# Fwd Packet Length Mean         0.037884
# Flow Duration                  0.020979
# Flow IAT Mean                  0.012248
# Fwd Packet Length Std          0.011286
# Bwd Packet Length Mean         0.008558
# Fwd IAT Total                  0.007980
# Flow IAT Min                   0.005533
# Flow IAT Max                   0.005458
# Flow Bytes/s                   0.004704
# Bwd Packet Length Std          0.004182
# Total Backward Packets         0.002774
# Bwd Packet Length Max          0.002724
# Fwd Packet Length Max          0.002285
# Flow Packets/s                 0.002272
# Total Length of Bwd Packets    0.002233
# Bwd Packet Length Min          0.002207
# Fwd Packet Length Min          0.002131
# Flow IAT Std                   0.001872
# Total Fwd Packets              0.001038
#
#
#
# Infiltration=["Total Length of Fwd Packets","Fwd Packet Length Mean","Flow Duration","Flow IAT Mean","Fwd Packet Length Std"]
# C:\Users\dhira\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\ipykernel_launcher.py:95: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error in 3.6
# -----------------------------------------------------------------------------------------------
#
#
#
#
# PortScan importance list:
# PortScan
#                                 importance
# Features
# Flow Bytes/s                 3.124927e-01
# Total Length of Fwd Packets  3.047099e-01
# Flow Duration                2.706583e-04
# Flow IAT Mean                2.413645e-04
# Flow IAT Max                 1.849425e-04
# Fwd IAT Total                1.682073e-04
# Fwd Packet Length Max        1.631713e-04
# Total Length of Bwd Packets  3.513060e-05
# Bwd Packet Length Min        2.437282e-05
# Total Fwd Packets            2.311768e-05
# Bwd Packet Length Mean       2.146794e-05
# Flow Packets/s               1.986928e-05
# Bwd Packet Length Std        1.940371e-05
# Flow IAT Min                 1.613470e-05
# Total Backward Packets       1.446566e-05
# Bwd Packet Length Max        1.386660e-05
# Fwd Packet Length Mean       1.191489e-05
# Flow IAT Std                 8.945851e-06
# Fwd Packet Length Std        8.310230e-06
# Fwd Packet Length Min        1.071182e-07
#
#
#
# PortScan=["Flow Bytes/s","Total Length of Fwd Packets","Flow Duration","Flow IAT Mean","Flow IAT Max"]
# C:\Users\dhira\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\ipykernel_launcher.py:95: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error in 3.6
# -----------------------------------------------------------------------------------------------
#
#
#
#
# SSH-Patator importance list:
# SSH-Patator
#                               importance
# Features
# Fwd Packet Length Max          0.000786
# Flow Duration                  0.000773
# Flow IAT Mean                  0.000674
# Flow IAT Max                   0.000630
# Total Length of Fwd Packets    0.000451
# Fwd IAT Total                  0.000329
# Flow Packets/s                 0.000282
# Flow Bytes/s                   0.000269
# Flow IAT Std                   0.000211
# Fwd Packet Length Mean         0.000181
# Flow IAT Min                   0.000147
# Fwd Packet Length Std          0.000118
# Total Backward Packets         0.000118
# Bwd Packet Length Min          0.000117
# Fwd Packet Length Min          0.000078
# Total Length of Bwd Packets    0.000040
# Bwd Packet Length Max          0.000036
# Bwd Packet Length Std          0.000032
# Bwd Packet Length Mean         0.000029
# Total Fwd Packets              0.000029
#
#
#
# SSH-Patator=["Fwd Packet Length Max","Flow Duration","Flow IAT Mean","Flow IAT Max","Total Length of Fwd Packets"]
# C:\Users\dhira\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\ipykernel_launcher.py:95: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error in 3.6
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Web Attack - Brute Force importance list:
# Web Attack - Brute Force
#                               importance
# Features
# Flow IAT Min                   0.002355
# Bwd Packet Length Std          0.002226
# Bwd Packet Length Max          0.002223
# Flow Bytes/s                   0.002120
# Fwd Packet Length Std          0.001055
# Total Fwd Packets              0.000504
# Fwd Packet Length Max          0.000421
# Total Length of Fwd Packets    0.000417
# Flow IAT Max                   0.000364
# Total Backward Packets         0.000319
# Flow IAT Mean                  0.000281
# Fwd Packet Length Mean         0.000275
# Flow Duration                  0.000216
# Flow Packets/s                 0.000160
# Total Length of Bwd Packets    0.000133
# Bwd Packet Length Mean         0.000128
# Flow IAT Std                   0.000092
# Fwd IAT Total                  0.000060
# Bwd Packet Length Min          0.000008
# Fwd Packet Length Min          0.000002
#
#
#
# Web Attack - Brute Force=["Flow IAT Min","Bwd Packet Length Std","Bwd Packet Length Max","Flow Bytes/s","Fwd Packet Length Std"]
# C:\Users\dhira\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\ipykernel_launcher.py:95: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error in 3.6
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Web Attack - Sql Injection importance list:
# Web Attack - Sql Injection
#                               importance
# Features
# Flow Bytes/s                   0.130432
# Fwd Packet Length Std          0.081319
# Fwd Packet Length Min          0.047794
# Bwd Packet Length Min          0.028441
# Flow IAT Min                   0.014437
# Bwd Packet Length Max          0.011996
# Fwd Packet Length Max          0.011299
# Fwd Packet Length Mean         0.010291
# Bwd Packet Length Std          0.008156
# Flow IAT Max                   0.008131
# Fwd IAT Total                  0.007707
# Total Length of Fwd Packets    0.007287
# Flow IAT Std                   0.007020
# Flow Duration                  0.006659
# Flow IAT Mean                  0.004692
# Flow Packets/s                 0.004569
# Bwd Packet Length Mean         0.000651
# Total Fwd Packets              0.000564
# Total Backward Packets         0.000449
# Total Length of Bwd Packets    0.000000
#
#
#
# Web Attack - Sql Injection=["Flow Bytes/s","Fwd Packet Length Std","Fwd Packet Length Min","Bwd Packet Length Min","Flow IAT Min"]
# C:\Users\dhira\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\ipykernel_launcher.py:95: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error in 3.6
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Web Attack - XSS importance list:
# Web Attack - XSS
#                               importance
# Features
# Total Length of Fwd Packets    0.007761
# Flow IAT Min                   0.002168
# Bwd Packet Length Std          0.002138
# Flow IAT Mean                  0.001343
# Bwd Packet Length Max          0.001091
# Fwd Packet Length Mean         0.000956
# Flow Packets/s                 0.000952
# Flow IAT Max                   0.000936
# Flow Duration                  0.000914
# Fwd Packet Length Std          0.000762
# Bwd Packet Length Mean         0.000537
# Fwd IAT Total                  0.000519
# Fwd Packet Length Max          0.000416
# Flow Bytes/s                   0.000355
# Total Length of Bwd Packets    0.000200
# Total Backward Packets         0.000170
# Total Fwd Packets              0.000099
# Flow IAT Std                   0.000081
# Bwd Packet Length Min          0.000008
# Fwd Packet Length Min          0.000000
#
#
#
# Web Attack - XSS=["Total Length of Fwd Packets","Flow IAT Min","Bwd Packet Length Std","Flow IAT Mean","Bwd Packet Length Max"]
# C:\Users\dhira\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\ipykernel_launcher.py:95: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error in 3.6
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Web Attack importance list:
# Web Attack
#                               importance
# Features
# Total Length of Fwd Packets    0.005705
# Bwd Packet Length Std          0.004425
# Bwd Packet Length Max          0.002099
# Flow Bytes/s                   0.001815
# Fwd Packet Length Mean         0.000945
# Flow IAT Max                   0.000748
# Fwd Packet Length Std          0.000679
# Flow Duration                  0.000649
# Flow Packets/s                 0.000613
# Flow IAT Mean                  0.000610
# Total Backward Packets         0.000583
# Flow IAT Min                   0.000529
# Total Fwd Packets              0.000387
# Fwd Packet Length Max          0.000328
# Fwd IAT Total                  0.000204
# Flow IAT Std                   0.000199
# Total Length of Bwd Packets    0.000182
# Bwd Packet Length Mean         0.000113
# Bwd Packet Length Min          0.000009
# Fwd Packet Length Min          0.000003
#
#
#
# Web Attack=["Total Length of Fwd Packets","Bwd Packet Length Std","Bwd Packet Length Max","Flow Bytes/s","Fwd Packet Length Mean"]
# C:\Users\dhira\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\ipykernel_launcher.py:95: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error in 3.6
# -----------------------------------------------------------------------------------------------
#
#
#
#
# mission accomplished!
# Total operation time: =  3879.147188425064 seconds
